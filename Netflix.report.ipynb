# %% [markdown]
# # Netflix Data Report

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\dipan\Downloads\netflix_india_2000_rows_12_columns.xlsx")

# %%
df.head(10)
# Out:
#   User_ID      User_Name     City       State Subscription_Plan  \
# 0   U0001     Amit Patel   Indore          MP          Standard
# 1   U0002   Rahul Sharma   Bhopal          MP             Basic
# 2   U0003     Sneha Iyer    Kochi      Kerala             Basic
# 3   U0004  Deepak Mishra   Kanpur          UP            Mobile
# 4   U0005   Vikram Singh  Chennai  Tamil Nadu             Basic
# 5   U0006    Ritu Saxena    Surat     Gujarat           Premium
# 6   U0007     Shweta Das    Surat     Gujarat           Premium
# 7   U0008     Shweta Das   Ranchi   Jharkhand          Standard
# 8   U0009  Deepak Mishra   Kanpur          UP             Basic
# 9   U0010   Anjali Desai    Patna       Bihar            Mobile
#
#    Plan_Price_INR Payment_Method  Start_Date     Status    Device  \
# 0             499           Card  2025-05-31  Cancelled    Mobile
# 1             199           Card  2025-09-25  Cancelled    Tablet
# ...

# %%
df.shape
# Out:
# (2000, 12)

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# User_Name            0
# City                 0
# State                0
# Subscription_Plan    0
# Plan_Price_INR       0
# Payment_Method       0
# Start_Date           0
# Status               0
# Device               0
# Favourite_Genre      0
# Monthly_Revenue      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['User_ID', 'User_Name', 'City', 'State', 'Subscription_Plan',
#        'Plan_Price_INR', 'Payment_Method', 'Start_Date', 'Status', 'Device',
#        'Favourite_Genre', 'Monthly_Revenue'],
#       dtype='object')

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User_ID            2000 non-null   object
#  1   User_Name          2000 non-null   object
#  2   City               2000 non-null   object
#  3   State              2000 non-null   object
#  4   Subscription_Plan  2000 non-null   object
#  5   Plan_Price_INR     2000 non-null   int64
#  6   Payment_Method     2000 non-null   object
#  7   Start_Date         2000 non-null   object
#  8   Status             2000 non-null   object
#  9   Device             2000 non-null   object
#  10  Favourite_Genre    2000 non-null   object
#  11  Monthly_Revenue    2000 non-null   int64
# dtypes: int64(2), object(10)
# memory usage: 187.6+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax=sns.countplot(x='Payment_Method' , data =df)

# %%
s_Qty=df.groupby(['Payment_Method'],as_index=False)['Monthly_Revenue'].sum().sort_values(by='Monthly_Revenue',ascending=False)
sns.barplot(x='Payment_Method',y='Monthly_Revenue',data=s_Qty)
# Out:
# <Axes: xlabel='Payment_Method', ylabel='Monthly_Revenue'>

# %%
import matplotlib.pyplot as plt

sizes = [30, 25, 15, 10, 20]  # Added one more value
labels = ['Action', 'Drama', 'Romance', 'comdy', 'Thriller']
colors = ['gold', 'lightcoral', 'red', 'yellow', 'green']

plt.figure(figsize=(4, 4))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title('Pie Chart Example')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

df.columns = df.columns.str.strip()

state_counts = df['State'].value_counts()

plt.bar(state_counts.index, state_counts.values)

plt.xlabel('State')
plt.ylabel('Count')
plt.title('Number of Records by State')

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

x = [199,149,3,4,5]
y = [10,15,7,12,9]

plt.plot(x, y, marker='o', linestyle='-', color='red')
plt.title("line chart")
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()
